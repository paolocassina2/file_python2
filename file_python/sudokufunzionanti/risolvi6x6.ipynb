# %%
import itertools
numeri=[x for x in range(1,7)]
per=[]

#risolve sudoku generico

#filtra all'inizio solamente in base alle cifre iniziali e poi in base ai quadrati e le colonne
a=['', '', '', 2, '', 5]
b=['', '', '', 1, 3, '']
c=[5, '', '', '', 6, '']
d=[6, 2, 3, 5, 1, '']
e=['', '', '', '', '', 3]
f=[4, '', 5, '', '', 1]
Sudoku=[a,b,c,d,e,f]
sol1,sol2,sol3,sol4,sol5,sol6=[],[],[],[],[],[]
conta_sud=-1
lista_ind1,lista_ind2,lista_ind3,lista_ind4,lista_ind5,lista_ind6=[],[],[],[],[],[]

s1,s2,s3,s4,s5,s6=[],[],[],[],[],[]
lista_lista_ind=[lista_ind1,lista_ind2,lista_ind3,lista_ind4,lista_ind5,lista_ind6]
lista_s=[s1,s2,s3,s4,s5,s6]
lista_sol=[sol1,sol2,sol3,sol4,sol5,sol6]
for x in Sudoku:
    print(x)
for sud in Sudoku:
    #print(sud)
    conta_sud=conta_sud+1
  
    
    for x1 in numeri:
        if x1 not in sud:
            #print(x1)
            lista_s[conta_sud].append(x1)
    
    for x in range(0,len(a)):
        if sud[x]=="":
            index1=x

            lista_lista_ind[conta_sud].append(index1)#fino a qui funziona


    
    for v in itertools.permutations(lista_s[conta_sud]):
        lista=["","","","","",""]
        
        conta=-1
       # print(v)

        for x3 in sud:
            conta=conta+1
          #  print(conta)
            #print(x3)

            
            for j ,y in zip(lista_lista_ind[conta_sud],v):
                if x3=="":
                    lista[j]=y
                else:
                    lista[conta]=x3
                
        lista_sol[conta_sud].append(lista)      

#ALGORITMO PER FILTRARE -->PER ESEMPIO PER OGNI RIGA FAR SCORRERE TUTTE LE ALTRE
for x in lista_sol:
    print(len(x))
print("###############")
print()
quadrato1=Sudoku[0][0:3]+Sudoku[1][0:3]  
quadrato2=Sudoku[0][3:6]+Sudoku[1][3:6]  
            

           
quadrato3=Sudoku[2][0:3]+Sudoku[3][0:3]  
quadrato4=Sudoku[2][3:6]+Sudoku[3][3:6]  
            
         
quadrato5=Sudoku[4][0:3]+Sudoku[5][0:3]  
quadrato6=Sudoku[4][3:6]+Sudoku[5][3:6]
def dizio():
        dizio.var={}
dizio()
#serve per memorizzare le cifre che ho già usato
conta=-1#posizionisudoku da 0 a 80(per sudoku 9x9) , posizioni da 0 a 35 (sudoku6x6)
def algoritmo():

    lista_cif=[]
    lista=[]

    lista_pos=[]
    conta=-1
    for volte in range(0,len(a)):
        
        for j,z in zip(Sudoku[volte],range(len(Sudoku[volte]))):#faccio scorrere una riga alla volta
                conta=conta+1
                riga=Sudoku[volte]
                colonna= [row[z] for row in Sudoku]
                
                #print("lkjdfkdfj",lista_riga)

             #  print("riga",riga)
              #  print("colonna",colonna)


                quadrato1=Sudoku[0][0:3]+Sudoku[1][0:3]  
                quadrato2=Sudoku[0][3:6]+Sudoku[1][3:6]  



                quadrato3=Sudoku[2][0:3]+Sudoku[3][0:3]  
                quadrato4=Sudoku[2][3:6]+Sudoku[3][3:6]  


                quadrato5=Sudoku[4][0:3]+Sudoku[5][0:3]  
                quadrato6=Sudoku[4][3:6]+Sudoku[5][3:6]

                if Sudoku[volte][z]=="":
                        lista_pos=[volte,z]
                        if z<=2:
                            for cif in numeri:

                                if volte==0 or volte==1:
                                    if cif not in colonna and cif not in riga and cif not in quadrato1:
                                        lista_cif.append(cif)
                                        lista=[lista_cif,lista_pos]
                                        #lista=[]
                                        dizio.var[str(conta)]=lista
                                        #Sudoku[volte][z]=cif
                                        #break
                                elif volte==2 or volte==3:
                                    if cif not in colonna and cif not in riga and cif not in quadrato3:    
                                       # lista=[]
                                        lista_cif.append(cif)
                                        lista=[lista_cif,lista_pos]
                                        
                                        dizio.var[str(conta)]=lista
                                       # Sudoku[volte][z]=cif
                                        #break
                                elif volte==4 or volte==5:
                                    if cif not in colonna and cif not in riga and cif not in quadrato5:
                                        #lista=[]
                                        lista_cif.append(cif)
                                        lista=[lista_cif,lista_pos]
                                       
                                        dizio.var[str(conta)]=lista
                                        #Sudoku[volte][z]=cif
                                        #break
                               # dizio.var[str(conta)]=[cif,volte,z]

                        else:
                                for cif in numeri:
                                    if volte==0 or volte==1:
                                        if cif not in colonna and cif not in riga and cif not in quadrato2:
                                          #  lista=[]
                                            lista_cif.append(cif)
                                            lista=[lista_cif,lista_pos]
                                        #Sudoku[volte][z]=cif
                                            dizio.var[str(conta)]=lista
                                            #Sudoku[volte][z]=cif
                                           #break
                                    elif volte==2 or volte==3:
                                        if cif not in colonna and cif not in riga and cif not in quadrato4:    
                                           # lista=[]   
                                            lista_cif.append(cif)
                                            lista=[lista_cif,lista_pos]
                                        #Sudoku[volte][z]=cif
                                            dizio.var[str(conta)]=lista
                                            #Sudoku[volte][z]=cif
                                            #  break
                                    elif volte==4 or volte==5:
                                        if cif not in colonna and cif not in riga and cif not in quadrato6:      

                                           
                                            lista_cif.append(cif)
                                        
                                            lista=[lista_cif,lista_pos]
                                            dizio.var[str(conta)]=lista
                                            #  break
                                           
                                           # Sudoku[volte][z]=cif

                else:
                      pass
                lista_cif=[]
                lista_pos=[]
                lista=[]
    print(dizio.var)
algoritmo()
#print(algoritmo())
#print(len(dizio.var))
#print(sol1)
#algoritmo()
def ciao():
    for x in dizio.var:
            if len(dizio.var[str(x)][0])==1:
                Sudoku[dizio.var[str(x)][1][0]][dizio.var[str(x)][1][1]]=dizio.var[str(x)][0][0]#assegno le cifre nelle posizioni dove è possibile una sola soluzione

                
for x in Sudoku:
    print(x)
soluzione1,soluzione2,soluzione3,soluzione4,soluzione5,soluzione6=[],[],[],[],[],[]
l_f=[]
vero=[]
intero1=0
intero2=6
n_lista=0
n=0
listasoluzioni_finali=[soluzione1,soluzione2,soluzione3,soluzione4,soluzione5,soluzione6]
l_f1,l_f2,l_f3,l_f4,l_f5,l_f6=[],[],[],[],[],[]
L_F=[l_f1,l_f2,l_f3,l_f4,l_f5,l_f6]
c=0
for x in range(37):#distribuisco il dizionario sulle varie righe
  
    if str(x) in dizio.var:
     
        if x<6:
            L_F[0].append(dizio.var[str(x)])
        elif 6<=x<=11:
            L_F[1].append(dizio.var[str(x)])
        elif 12<=x<=17:
            L_F[2].append(dizio.var[str(x)])
       
        elif 18<=x<=23:
            L_F[3].append(dizio.var[str(x)])
        elif 24<=x<=29:
            L_F[4].append(dizio.var[str(x)])
        elif 30<=x<=35:
            L_F[5].append(dizio.var[str(x)])
                #l_f.append(dizio.var[str(x)])
           # if x%6==0:

             #   L_F.append(dizio.var[str(x)])
print("lf1",L_F[1])
#print(lista_sol[5],"sol5")
#print("ddl",len(L_F[5]))
for scorrilista in range(len(lista_sol)):
    for j in lista_sol[scorrilista]:

        cc=0

        for x in L_F[scorrilista]:
                if j[x[1][1]] in x[0]:
                    cc=cc+1
                    if cc==len(L_F[scorrilista]):
                            listasoluzioni_finali[scorrilista].append(j)

#for j in lista_sol[1]:
  
 #   for x in L_F[1]:
 #       cc=0
 #       print(x[0])
            
                    
#stampa tutte le soluzioni possibili , dopo che le soluzioni sono state filtreate , in base alle cifre che le righe possono avere in certe posizioni
for x in listasoluzioni_finali:
    print( "ciaooooooo",x)
lista_vero=[]
trovato=False
for j1 in listasoluzioni_finali[0]:
    if trovato==True:
        break
    for j2 in listasoluzioni_finali[1]:
        if trovato==True:
            break
        for j3 in listasoluzioni_finali[2]:
            if trovato==True:
                break
            for j4 in listasoluzioni_finali[3]:
                if trovato==True:
                        break
                for j5 in listasoluzioni_finali[4]:
                    if trovato==True:
                        break
                    for j6 in listasoluzioni_finali[5]:
    
                        Sudoku=[j1,j2,j3,j4,j5,j6]



                        colonna1= [row[0] for row in Sudoku]
                                 
                        colonna2=    [    row[1]   for row in Sudoku ]
                        colonna3=      [       row[2] for row in Sudoku ]
                        colonna4=      [      row[3]  for row in Sudoku ]
                        colonna5=      [       row[4] for row in Sudoku ]
                        colonna6=      [       row[5]  for row in Sudoku]
                        
                        COLONNE=[ len(list(set (colonna1)))==len(colonna1),
                            
                         len(list(set (colonna2)))==len(colonna2),
                            
                       len(list(set (colonna3)))==len(colonna3),
                        len(list(set (colonna4)))==len(colonna4),
                         len(list(set (colonna5)))==len(colonna5),
                        len(list(set (colonna6)))==len(colonna6)]
                       
                        quadrato1=Sudoku[0][0:3]+Sudoku[1][0:3]  
                        quadrato2=Sudoku[0][3:6]+Sudoku[1][3:6]  



                        quadrato3=Sudoku[2][0:3]+Sudoku[3][0:3]  
                        quadrato4=Sudoku[2][3:6]+Sudoku[3][3:6]  


                        quadrato5=Sudoku[4][0:3]+Sudoku[5][0:3]  
                        quadrato6=Sudoku[4][3:6]+Sudoku[5][3:6]
                        ciao=[ len(list(set (quadrato1)))==len(quadrato1),
                            
                         len(list(set (quadrato2)))==len(quadrato2),
                            
                       len(list(set (quadrato3)))==len(quadrato3),
                        len(list(set (quadrato4)))==len(quadrato4),
                         len(list(set (quadrato5)))==len(quadrato5),
                        len(list(set (quadrato6)))==len(quadrato6)]
                        if False not in ciao and False not in COLONNE:
                            trovato=True
                            for x in Sudoku:
                                print(x)
                               

                        

def ciao():
    for j in lista_sol[1]:
        if j[0]==2 and (j[1]==4 or j[1]==5 or j[1]==6) and (j[2]==2 or j[2]==4 or j[2]==6) and (j[5]== 4 or j[5]==6):
            print(j)
# Out:
# ['', '', '', 2, '', 5]
# ['', '', '', 1, 3, '']
# [5, '', '', '', 6, '']
# [6, 2, 3, 5, 1, '']
# ['', '', '', '', '', 3]
# [4, '', 5, '', '', 1]
# 24
# 24
# 24
# 1
# 120
# 6
# ###############
#
# {'0': [[1, 3], [0, 0]], '1': [[1, 3, 4, 6], [0, 1]], '2': [[1, 4, 6], [0, 2]], '4': [[4], [0, 4]], '6': [[2], [1, 0]], '7': [[4, 5, 6], [1, 1]], '8': [[2, 4, 6], [1, 2]], '11': [[4, 6], [1, 5]], '13': [[1, 4], [2, 1]], '14': [[1, 4], [2, 2]], '15': [[3, 4], [2, 3]], '17': [[2, 4], [2, 5]], '23': [[4], [3, 5]], '24': [[1, 2], [4, 0]], '25': [[1, 6], [4, 1]], '26': [[1, 2, 6], [4, 2]], '27': [[4, 6], [4, 3]], '28': [[2, 4, 5], [4, 4]], '31': [[3, 6], [5, 1]], '33': [[6], [5, 3]], '34': [[2], [5, 4]]}
# ['', '', '', 2, '', 5]
# ['', '', '', 1, 3, '']
# [5, '', '', '', 6, '']
# [6, 2, 3, 5, 1, '']
# ['', '', '', '', '', 3]
# [4, '', 5, '', '', 1]
# lf1 [[[2], [1, 0]], [[4, 5, 6], [1, 1]], [[2, 4, 6], [1, 2]], [[4, 6], [1, 5]]]
# ...

# %%
def ciao():
                #print(dizio.var[str(x)],"cifre, posizione")
                for j in lista_sol[n_lista]:
                    for y in j:
                        if y in dizio.var[str(x)][0]:
                            vero.append(True)
                            if len(vero)>=len(dizio.var[str(x)][0]):
                                listasoluzioni_finali[n_lista].append(j)
                                
                                intero1+=6
                                intero2+=6
                        n_lista=n_lista+1       
                                 
               # for j in sol5:
               # for j in sol6:#filtro ulteriormetne per trovare soluzioni della terza riga

                #print(j[dizio.var[str(x)][1][1]])
                #in dizio.var[str(x)][0][0]:
                 #       soluzione5.append(j)
print("#####################")

#for x,j in zip(listasoluzioni_finali,range(1,7)):
 #   print(x,j)

def ciao():    
      #  if j[1] in dizio.var[str(13)][0] or j[2] in dizio.var[str(14)][0] or j[3] in dizio.var[str(15)][0] or j[5] in dizio.var[str(17)][0]:
     # if (j[1]== 0 or j[1]==4)   and (j[2]==1 or j[2]==4) and  (j[3]==3 or j[3]==4) and (j[5]==2 or j[5]==4):#specifico , renderlo più generico
    soluzione3.append(j)
    print(len(soluzione3))

    #print(soluzione3)
    for j in sol5:#filtro ulteriormetne per trovare soluzioni della terza riga
      #  if j[1] in dizio.var[str(13)][0] or j[2] in dizio.var[str(14)][0] or j[3] in dizio.var[str(15)][0] or j[5] in dizio.var[str(17)][0]:
      if (j[0]== 1 or j[0]==2)   and (j[1]==1 or j[1]==6) and  (j[2]==1 or j[2]==2 or j[2]==6 ) and (j[3]==4 or j[3]==6) and (j[4]==2 or j[4]==4 or j[4]==5) :
        soluzione5.append(j)  
    for j in sol6:#filtro ulteriormetne per trovare soluzioni della terza riga
      #  if j[1] in dizio.var[str(13)][0] or j[2] in dizio.var[str(14)][0] or j[3] in dizio.var[str(15)][0] or j[5] in dizio.var[str(17)][0]:
      if   (j[1]==3 or j[1]==6)  and j[3]==6 and j[4]==2  :
        soluzione6.append(j)    
    
    #print(soluzione3)
    #print(soluzione5)
    #print(soluzione6)
# Out:
# #####################
