# %% [markdown]
# ### SUDOKU SOLVER WITH PERMUTATIONS

# %% [markdown]
# LI RISOLVE TUTTI CON LE PERMUTAZIONI , ANCHE I PIU DIFFICILI, ELIMINATI I DEEPLY NESTED LOOPS, NON SONO PIù COSI ANNIDATI e infatti i tempi di risoluzione sono molto più bassi.
# TEMPi DI RISOLUZIONE: i sudoku facili vengono risolti in meno di un secondo,medi e difficili vengono in qualche secondo, (da 1 a 3 secondi) mentre
#                        i sudoku molto difficili vengono risolti in poco più di un minuto.
#
# algoritmo:filtra le permutazioni in base alle cifre iniziali, poi in base alle cifre che può contenere ogni cella vuota, poi cerca di "incastrare" tra loro tre righe alla volta ,
# dopodiché cerca le soluzioni possibili delle prime sei righe ed infine la soluzione finale

# %% [markdown]
# per scegliere quale sudoku risolvere, bisogna commentare la definizione di funzione ed eliminare le indentazioni prima di a,b,c ecc. e controllare che tutti gli altri sudoku siano all'interno di una funzione in modo che vengano ignorati dal programma

# %%
#inputsudoku()
import itertools
from datetime import datetime
inizio = datetime.now()
numeri=[x for x in range(1,10)]
per=[]
#risolve solo i sudokufacili
def sudoku_medio():
    a=[9, 2, 6, '', '', 8, '', 1, '']
    b=['', 5, 8, '', 2, '', 3, '', 7]
    c=['', '', '', 5, '', '', 8, 2, '']
    d=['', 9, '', '', 5, 7, '', '', '']
    e=['', '', 3, 9, '', '', '', 7, '']
    f=['', '', '', 6, 1, '', '', '', 5]
    g=[4, 6, '', '', '', '', 7, '', '']
    h=['', '', '', '', '', '', '', 8, '']
    k=[2, '', 1, '', '', '', 6, 9, '']
#sudoku_medio()
#LI RISOLVE TUTTI CON LE PERMUTAZIONI , ANCHE I PIU DIFFICILI, ELIMINATI I DEEPLY NESTED LOOPS, NON SONO PIù COSI ANNIDATI.

#algoritmo:filtra le permutazioni in base alle cifre iniziali, poi in base alle cifre che può contenere ogni cella vuota (solo le cifre della permutazione in corrispondneza delle celle vuote  corrispondono tante volte quando il numero di celle vuote in ogni riga), poi cerca di "incastrare" tra loro tre righe alla volta ,
#poi cerca le soluzioni possibili delle prime sei righe ed infine la soluzione finale
def sudokucon2soluzioni():

    a=[9, '', 6, '', 7, '', 4, '', 3]
    b=['', '', '', 4, '', '', 2, '', '']
    c=['', 7, '', '', 2, 3, '', 1, '']
    d=[5, '', '', '', '', '', 1, '', '']
    e=['', 4, '', 2, '', 8, '', 6, '']
    f=['', '', 3, '', '', '', '', '', 5]
    g=['', 3, '', 7, '', '', '', 5, '']
    h=['', '', 7, '', '', 5, '', '', '']
    k=[4, '', 5, '', 1, '', 7, '', 8]


def sudokudiabolico():
    a=['', 7, '', '', '', 1, '', '', 5]#0:00:47.730255 tempo risoluzine
    b=['', 4, '', 5, 2, '', '', 6, '']
    c=['', '', 2, '', '', 3, '', '', '']
    d=['', '', '', 1, '', '', '', '', '']
    e=['', '', 8, 4, 5, '', '', '', 7]
    f=[7, '', '', '', '', '', '', 3, '']
    g=['', '', '', '', '', 2, '', '', '']
    h=['', '', 4, 7, 8, '', '', '', 3]
    k=['', 6, '', '', '', '', 9, '', '']

def verydifficult():
    a=[6, '', 3, '', '', '', 1, '', '']
    b=['', '', 9, '', '', '', 2, '', '']
    c=['', '', 7, 4, '', 9, '', '', '']#in realtà non e cosi difficile , risolto in 01.73064 secondi
    d=['', '', '', '', 1, '', '', '', 7]
    e=[4, '', '', '', 6, '', '', '', '']
    f=['', '', '', '', 7, '', '', 5, 3]
    g=['', 1, '', '', '', '', '', 4, '']
    h=['', '', 6, 3, '', 7, '', 9, '']
    k=['', 9, '', '', '', 2, '', 3, '']
#risolve sudoku facili e hard in secondi e quelli più difficili in poco piu di un minuto(esperoto e difficile)
 # t
def ciao():
    a= ['', '', '', '', 3, '', 2, '', '']#sudokufacile2
    b= [7, '', 5, 2, '', '', '', 9, ''] #tempo risoluzione 0:00:00.364029,--> 3 decimi
    c= [8, 3, '', 4, 6, 9, 1, 5, '']
    d= [2, '', '', '', 9, 4, '', 3, '']
    e= [9, 8, '', '', '', 3, '', '', 2]
    f= [6, 1, 3, 8, '', 2, '', '', 9]
    g= [4, '', '', 1, '', '', 7, '', 3]
    h= [3, 7, 8, '', 2, '', 4, '', '']
    k= ['', 6, 1, '', '', '', '', '', '']
def l_p():
    l_p.var=""
l_p()

l_p.var=[[] for x in range(9)]
print(l_p.var)
soluzioni_facile=[
[1, 9, 6, 7, 3, 5, 2, 8, 4],#per controllare la correttezza delle soluzioni, se il programma restituisce le soluzioni corrette
[7, 4, 5, 2, 8, 1, 3, 9, 6],
[8, 3, 2, 4, 6, 9, 1, 5, 7],
[2, 5, 7, 6, 9, 4, 8, 3, 1],
[9, 8, 4, 5, 1, 3, 6, 7, 2],
[6, 1, 3, 8, 7, 2, 5, 4, 9],
[4, 2, 9, 1, 5, 8, 7, 6, 3],
[3, 7, 8, 9, 2, 6, 4, 1, 5],
[5, 6, 1, 3, 4, 7, 9, 2, 8]]


def sudokudifficile2():
    a= [9, '', '', '', 2, 7, '', 5, '']
    b= ['', 5, '', '', '', '', 9, '', 4]
    c= ['', '', '', '', '', '', '', '', '']
    d= [8, '', '', '', 7, 5, 6, 4, 9]
    e= [1, '', '', '', 4, '', '', '', '']
    f= ['', '', '', '', '', 9, 8, '', '']
    g= ['', '', '', 4, '', '', '', '', '']
    h= ['', '', '', '', 3, '', '', 1, '']
    k= [5, '', 1, '', '', 2, '', 3, 7]


#soluzionedifficile2
#difficile=[[9, 8, 4, 6, 2, 7, 1, 5, 3],
#[2, 5, 7, 8, 1, 3, 9, 6, 4], tempo risoluzione  con nuovo algoritmo0:01:17.811564(1 minuto 17 secondi)
#[6, 1, 3, 5, 9, 4, 7, 8, 2 ],
#[8, 3, 2, 1, 7, 5, 6, 4, 9],                    altro tempo di risoluzione con nuovo algoritmo 0:01:08.030196 minuto
#[1, 9, 6, 2, 4, 8, 3, 7, 5 ],
#[7, 4, 5, 3, 6, 9, 8, 2, 1],
#3, 7, 8, 4, 5, 1, 2, 9, 6],
#[4, 2, 9, 7, 3, 6, 5, 1, 8],
#[5, 6, 1, 9, 8, 2, 4, 3, 7]]
def quadrato1():
        quadrato1.var=""
quadrato1()
def    quadrato2():
        quadrato2.var=""
quadrato2()
def    quadrato3():
        quadrato3.var=""
quadrato3()
def    quadrato4():
        quadrato4.var=""
quadrato4()
def     quadrato5():
        quadrato5.var=""
quadrato5()
def    quadrato6():
        quadrato6.var=""
quadrato6()
def    quadrato7():
        quadrato7.var=""
quadrato7()
def    quadrato8():
        quadrato8.var=""
quadrato8()
def    quadrato9():
        quadrato9.var=""

quadrato9()
def controllo_ok():
    controllo_ok.var=""
controllo_ok()
def CHECK_colonna():
    CHECK_colonna.var=[]
CHECK_colonna()

def CHECK_quadrato():
     CHECK_quadrato=""
CHECK_quadrato()
#
def Sudoku():
    Sudoku.var=""
Sudoku()
#def difficoltaesperto():
a= ['', '', 5, '', '', 8, 3, 9, '']#0:01:26.741832 tempo risoluzione con nuovo algoritmo(1 MINUTO E 26 secondi)

b= ['', 3, '', '', '', '', '', '', '']#nuovo tempo risoluzione  0:01:06.303514 con nuovo algoritmo (1 minuto e 6 secondi)
c= ['', '', '', 7, '', '', '', 8, '']
d= ['', '', 4, 5, '', '', 6, '', 2]
e= [6, 1, '', '', '', '', '', '', '']
f= [2, '', '', '', 4, 9, '', '', '']
g= ['', '', '', '', '', 2, 4, '', 5]
h= ['', '', 9, '', 8, '', '', '', '']
k= [5, 6, '', '', '', '', '', '', '']

    
listasoluzioniesperto=[[7, 4, 5, 2, 1, 8, 3, 9, 6],#esperto
[8, 3, 2, 4, 9, 6, 1, 5, 7],#s
[1, 9, 6, 7, 5, 3, 2, 8, 4],
[9, 8, 4, 5, 3, 1, 6, 7, 2],
[6, 1, 3, 8, 2, 7, 5, 4, 9],
[2, 5, 7, 6, 4, 9, 8, 3, 1],
[3, 7, 8, 9, 6, 2, 4, 1, 5],
[4, 2, 9, 1, 8, 5, 7, 6, 3],#
[5, 6, 1, 3, 7, 4, 9, 2, 8] ]
def hard():
    a=['', '', 4, 7, 5, '', '', 6, '']
    b=['', '', 2, '', 3, 8, 4, '', '']#
    c=[3, 6, '', '', '', '', '', '', '']
    d=['', 3, 9, '', '', '', '', '', 1]#
    e=[7, '', 1, '', '', '', '', '', '']
    f=['', '', '', 4, '', 1, '', 9, 6]# 1
    g=[1, '', '', 9, '', 3, '', 8, '']#sbno 
    h=['', 2, '', '', '', '', '', '', 4]#l
    k=['', '', '', '', 8, '', '', 5, ''] 



#soluzione sudokuhard
#[9, 1, 4, 7, 5, 2, 8, 6, 3]tempo risoluzione0:54minuti:52.208947 algorimto annidato 9 volte
#[5, 7, 2, 6, 3, 8, 4, 1, 9]
#[3, 6, 8, 1, 9, 4, 2, 7, 5]
#[6, 3, 9, 8, 2, 5, 7, 4, 1]0:00:01.734984secondo con nuovo algorimto
#[7, 4, 1, 3, 6, 9, 5, 2, 8]
#[2, 8, 5, 4, 7, 1, 3, 9, 6]
#[1, 5, 7, 9, 4, 3, 6, 8, 2]
#[8, 2, 6, 5, 1, 7, 9, 3, 4]
#[4, 9, 3, 2, 8, 6, 1, 5, 7]#
def sudokufacile():
    a=["",4,1,"","",9,6,"",8]#LISTA COMBINAZIONI RIGA 7 SE FILTRATA IN BASE ALLE COMBINAZIONE DELLA RIGA 2 VIENE RIDOTTA DA CIRCA 40000 A 16687 COMBINAZIONI POSSIBILI

    b=[6,"","","","","","",3,""]

    c=["","","",2,7,"","",9,""]

    d=["",8,"","","","",1,5,""]
    e=[3,5,"","","","","","",""]
    f=["","","","",6,8,"",2,""]

    g=[7,"",8,"","",5,"","",4]
    h=["","",9,4,"","",7,"",3]
    k=["","","",1,"","",2,"",""]

#[2, 4, 1, 3, 5, 9, 6, 7, 8]
#[6, 9, 7, 8, 1, 4, 5, 3, 2]
#[8, 3, 5, 2, 7, 6, 4, 9, 1]
#[9, 8, 2, 7, 4, 3, 1, 5, 6]
#[3, 5, 6, 9, 2, 1, 8, 4, 7]
#[1, 7, 4, 5, 6, 8, 3, 2, 9]
#[7, 2, 8, 6, 3, 5, 9, 1, 4]
#[5, 1, 9, 4, 8, 2, 7, 6, 3]
#[4, 6, 3, 1, 9, 7, 2, 8, 5]


def colonna():
    colonna.var=""
colonna()

Sudoku.var=[a,b,c,d,e,f,g,h,k]
print("Sudoku iniziale")
for xj in Sudoku.var:
    print(xj)
print()

                
      
def crea_funzione_check_colonne_e_quadrati():#funzione che serve per verificare la correttezza della soluzione finale
    #ignoro i "" nelle colonne e quadrati
                        colonna1= [row[0] for row in Sudoku.var]

                        colonna2=    [    row[1]   for row in Sudoku.var]
                        colonna3=      [       row[2] for row in Sudoku.var ]
                        colonna4=      [      row[3]  for row in Sudoku.var ]
                        colonna5=      [       row[4] for row in Sudoku.var ]
                        colonna6=      [       row[5]  for row in Sudoku.var]
                        colonna7=      [       row[6]  for row in Sudoku.var]
                        colonna8=      [       row[7]  for row in Sudoku.var]

                        colonna9=      [       row[8]  for row in Sudoku.var]

                        if len(Sudoku.var)==9:
                            quadrato1.var=Sudoku.var[0][0:3]+Sudoku.var[1][0:3]  +Sudoku.var[2][0:3]
                            quadrato2.var=Sudoku.var[0][3:6]+Sudoku.var[1][3:6]  +Sudoku.var[2][3:6]
                            quadrato3.var=Sudoku.var[0][6:9]+Sudoku.var[1][6:9]   +Sudoku.var[2][6:9]

                            quadrato4.var=Sudoku.var[3][0:3]+Sudoku.var[4][0:3]  +Sudoku.var[5][0:3]
                            quadrato5.var=Sudoku.var[3][3:6]+Sudoku.var[4][3:6]  +Sudoku.var[5][3:6]
                            quadrato6.var=Sudoku.var[3][6:9]+Sudoku.var[4][6:9]   +Sudoku.var[5][6:9]

                            quadrato7.var=Sudoku.var[6][0:3]+Sudoku.var[7][0:3]  +Sudoku.var[8][0:3]
                            quadrato8.var=Sudoku.var[6][3:6]+Sudoku.var[7][3:6]  +Sudoku.var[8][3:6]
                            quadrato9.var=Sudoku.var[6][6:9]+Sudoku.var[7][6:9]   +Sudoku.var[8][6:9]
                            CHECK_riga=[x for x in Sudoku.var]
                            CHECK_colonna.var=[colonna1,colonna2,colonna3,colonna4,colonna5,colonna6,colonna7,colonna8,colonna9]
                            CHECK_quadrato.var=[quadrato1.var,quadrato2.var,quadrato3.var,quadrato4.var,quadrato5.var,quadrato6.var,quadrato7.var,quadrato8.var,quadrato9.var]
                       # print("checkcolonna",CHECK_colonna)

                        if len(Sudoku.var)==6:#per controllo finale
                            quadrato1.var=Sudoku.var[0][0:3]+Sudoku.var[1][0:3]  +Sudoku.var[2][0:3]
                            quadrato2.var=Sudoku.var[0][3:6]+Sudoku.var[1][3:6]  +Sudoku.var[2][3:6]
                            quadrato3.var=Sudoku.var[0][6:9]+Sudoku.var[1][6:9]   +Sudoku.var[2][6:9]

                            quadrato4.var=Sudoku.var[3][0:3]+Sudoku.var[4][0:3]  +Sudoku.var[5][0:3]
                            quadrato5.var=Sudoku.var[3][3:6]+Sudoku.var[4][3:6]  +Sudoku.var[5][3:6]
                            quadrato6.var=Sudoku.var[3][6:9]+Sudoku.var[4][6:9]   +Sudoku.var[5][6:9]
                            CHECK_riga=[Sudoku.var[0],Sudoku.var[1],Sudoku.var[2],Sudoku.var[3],Sudoku.var[4],Sudoku.var[5]]
                            CHECK_colonna.var=[colonna1,colonna2,colonna3,colonna4,colonna5,colonna6,colonna7,colonna8,colonna9]

                            CHECK_quadrato.var=[quadrato1.var,quadrato2.var,quadrato3.var,quadrato4.var,quadrato5.var,quadrato6]

                        if len(Sudoku.var)==3:#per controllo finale
                                quadrato1.var=Sudoku.var[0][0:3]+Sudoku.var[1][0:3]  +Sudoku.var[2][0:3]
                                quadrato2.var=Sudoku.var[0][3:6]+Sudoku.var[1][3:6]  +Sudoku.var[2][3:6]
                                quadrato3.var=Sudoku.var[0][6:9]+Sudoku.var[1][6:9]   +Sudoku.var[2][6:9]
                                CHECK_riga=[Sudoku.var[0],Sudoku.var[1],Sudoku.var[2]]
                                CHECK_colonna.var=[colonna1,colonna2,colonna3,colonna4,colonna5,colonna6,colonna7,colonna8,colonna9]

                                CHECK_quadrato.var=[quadrato1.var,quadrato2.var,quadrato3.var]
                          #  quadrato4=Sudoku.var[3][0:3]+Sudoku.var[4][0:3]  +Sudoku.var[5][0:3]
                           # quadrato5=Sudoku.var[3][3:6]+Sudoku.var[4][3:6]  +Sudoku.var[5][3:6]
                            #quadrato6=Sudoku.var[3][6:9]+Sudoku.var[4][6:9]   +Sudoku.var[5][6:9]





                        #numbers = [1, "", "", 4, 5, 6, 7, 8, 9,"", 10]
                        #jjk = [1, "", "", "f", "jkjdkfjdk", 6, 7, 8, 9, 10]
                        #sudoku=[numbers,jjk]
                        COLONNE=[]
                        RIGHE=[]
                        ciao2=[]
                        def senzaspazi(number):
                            if number  == "":
                                  return False

                            return True

                        for x in CHECK_colonna.var:
                        # Extract elements from the numbers list for which check_even() returns True
                            senza_spazi_iterator = filter(senzaspazi,x )

                            # converting to list
                            CHECK_colonna_senza_spazi = list(senza_spazi_iterator)
                            #print("senza s",CHECK_colonna_senza_spazi )
                            COLONNE.append(len(set(CHECK_colonna_senza_spazi ))==len(CHECK_colonna_senza_spazi ))
                            #print(Sudoku.var)
                       # print(COLONNE)
                        for x in CHECK_quadrato.var:
                        # Extract elements from the numbers list for which check_even() returns True
                            senza_spazi_iterator = filter(senzaspazi,x )

                            # converting to list
                            CHECK_quadrato_senza_spazi = list(senza_spazi_iterator)
                            #print("senza s",CHECK_quadrato_senza_spazi )
                            ciao2.append(len(set(CHECK_quadrato_senza_spazi ))==len(CHECK_quadrato_senza_spazi ))                       # CHECK_quadrato_set=[]
                        for x in CHECK_riga:
                        # Extract elements from the numbers list for which check_even() returns True
                            senza_spazi_iterator = filter(senzaspazi,x )

                            # converting to list
                            CHECK_riga_senza_spazi = list(senza_spazi_iterator)
                            #print("senza s",CHECK_riga_senza_spazi )
                            RIGHE.append(len(set(CHECK_riga_senza_spazi ))==len(CHECK_riga_senza_spazi ))
                            # CHECK_riga_set=[]
                       # print(RIGHE)
                        #print(COLONNE)
                        #print(ciao2)
                      #  for x in Sudoku.var:
                       #     print(len(x))

                        #for x in CHECK_righe:
                         #   print("ccÃ¹",x)
                        if False not in ciao2 and False not in COLONNE and False not in RIGHE :
                        #if False not in ciao2 and False not in COLONNE and False not in righe:
                           # print("ciao")

                            #print("ciao")
                           # for x in Sudoku.var:
                            #    print(x)
                            #print("ciao")
                            controllo_ok.var=True
                            return "non ci sono errori"
                            def ciao():
                                print("non ci sono errori")

                        else:
                            controllo_ok.var=False
                            return "presenti errori"
                            #def ciao():
                            if False in ciao2:
                                    for x in range(len(ciao2)):
                                        if ciao2[x]==False:

                                            print("errore_quadrati",x)
                            if False in COLONNE:
                                    for x in range(len(COLONNE)):
                                        if COLONNE[x]==False:


                                            print("errore_colonne",x)
                            if False in RIGHE:
                                    for x in range(len(RIGHE)):
                                        if RIGHE[x]==False:
                                            print("errore_righe",x)
                        contavirgolette=0
                        if len(Sudoku.var)==9:
                            for x in Sudoku.var:
                                if False not in ciao2 and False not in COLONNE and False not in RIGHE :
                                    if "" not in x:
                                        contavirgolette+=1
                                        if contavirgolette==0:
                                            controllo_ok.var=True
                                            print("IL SUDOKU E STATO RISOLTO CORRETTAMENTE")
                        #print(CHECK_colonna)


                        if  controllo_ok.var==True:
                            return "no errori"
                        else:
                            return "presenti errrori"
                        #print("aaaaaaadffdfdddddddddddddddd")
                       # for x in Sudoku.var:
                         #    print(x)
crea_funzione_check_colonne_e_quadrati()

                  #  print("x,y,valore")
                   # print(dizio.var[str(int_chiave)][1][0],[dizio.var[str(int_chiave)][1][1]],dizio.var[str(int_chiave)][0][0])
                 #    Sudoku.var[dizio.var[str(int_chiave)][1][0]][dizio.var[str(int_chiave)][1][1]]=""
                  #  if dizio.var[str(int_chiave)][0][0] in Sudoku.var[riga]:
                   #         print("errore riga",riga)

                    #if  dizio.var[str(int_chiave)][0][0]  in CHECK_colonna.var[verticale]  :
                     #   print("errore colonna",verticale,CHECK_colonna.var[verticale])
                    #if dizio.var[str(int_chiave)][0][0] in CHECK_quadrato.var[indice_quadrato]:
                     #   print("errore quadrato,",  CHECK_quadrato.var[indice_quadrato] )
              #  algoritmo()

conta=-1
def dizio():
            dizio.var={}
dizio()   
def algoritmo():#funzione che cerca le soluzioni possibili per ogni singola cella vuota
   
    def ciao():
        quadrato1.var=Sudoku.var[0][0:3]+Sudoku.var[1][0:3]  +Sudoku.var[2][0:3]
        quadrato2.var=Sudoku.var[0][3:6]+Sudoku.var[1][3:6]  +Sudoku.var[2][3:6]
        quadrato3.var=Sudoku.var[0][6:9]+Sudoku.var[1][6:9]   +Sudoku.var[2][6:9]

        quadrato4.var=Sudoku.var[3][0:3]+Sudoku.var[4][0:3]  +Sudoku.var[5][0:3]
        quadrato5.var=Sudoku.var[3][3:6]+Sudoku.var[4][3:6]  +Sudoku.var[5][3:6]
        quadrato6.var=Sudoku.var[3][6:9]+Sudoku.var[4][6:9]   +Sudoku.var[5][6:9]
        quadrato7.var=Sudoku.var[6][0:3]+Sudoku.var[7][0:3]  +Sudoku.var[8][0:3]
        quadrato8.var=Sudoku.var[6][3:6]+Sudoku.var[7][3:6]  +Sudoku.var[8][3:6]
        quadrato9.var=Sudoku.var[6][6:9]+Sudoku.var[7][6:9]   +Sudoku.var[8][6:9]
    conta=-1
    contaspazi=0
    lista_cif=[]
    lista=[]

    lista_pos=[]
    quadrato1.var=Sudoku.var[0][0:3]+Sudoku.var[1][0:3]  +Sudoku.var[2][0:3]
    quadrato2.var=Sudoku.var[0][3:6]+Sudoku.var[1][3:6]  +Sudoku.var[2][3:6]
    quadrato3.var=Sudoku.var[0][6:9]+Sudoku.var[1][6:9]   +Sudoku.var[2][6:9]

    quadrato4.var=Sudoku.var[3][0:3]+Sudoku.var[4][0:3]  +Sudoku.var[5][0:3]
    quadrato5.var=Sudoku.var[3][3:6]+Sudoku.var[4][3:6]  +Sudoku.var[5][3:6]
    quadrato6.var=Sudoku.var[3][6:9]+Sudoku.var[4][6:9]   +Sudoku.var[5][6:9]
    quadrato7.var=Sudoku.var[6][0:3]+Sudoku.var[7][0:3]  +Sudoku.var[8][0:3]
    quadrato8.var=Sudoku.var[6][3:6]+Sudoku.var[7][3:6]  +Sudoku.var[8][3:6]
    quadrato9.var=Sudoku.var[6][6:9]+Sudoku.var[7][6:9]   +Sudoku.var[8][6:9]
    
    for volte in range(0,len(numeri)):


                for j,z in zip(Sudoku.var[volte],range(len(Sudoku.var[volte]))):#faccio scorrere una riga alla volta
                        conta=conta+1
                        riga=Sudoku.var[volte]
                        colonna.var= [row[z] for row in Sudoku.var]
                        #print(riga)
                        #print(colonna)
                        #print("lkjdfkdfj",lista_riga)

                     #  print("riga",riga)
                      #  print("colonna",colonna)

                        #elif len(numeri)==9:
                   

                        if Sudoku.var[volte][z]=="":
                                contaspazi+=1
                                lista_pos=[volte,z]
                                if z<=2:
                                    for cif in numeri:

                                        if volte==0 or volte==1 or volte==2:
                                            if cif not in colonna.var and cif not in riga and cif not in quadrato1.var:


                                                lista_cif.append(cif)

                                                lista=[lista_cif,lista_pos]
                                                dizio.var[str(conta)]=lista
                                                #  break
                                        elif volte==3 or volte==4 or volte==5:
                                            if cif not in  colonna.var and cif not in riga and cif not in quadrato4.var:
                                                lista_cif.append(cif)

                                                lista=[lista_cif,lista_pos]
                                                dizio.var[str(conta)]=lista

                                        elif volte==6 or volte==7 or volte==8:
                                            if cif not in  colonna.var and cif not in riga and cif not in quadrato7.var:

                                                lista_cif.append(cif)

                                                lista=[lista_cif,lista_pos]
                                                dizio.var[str(conta)]=lista

                                elif 3<=z<=5:
                                        for cif in numeri:
                                            if volte==0 or volte==1 or volte==2:
                                                if cif not in  colonna.var and cif not in riga and cif not in quadrato2.var:
                                                    lista_cif.append(cif)

                                                    lista=[lista_cif,lista_pos]
                                                    dizio.var[str(conta)]=lista
                                            elif volte==3 or volte==4 or volte==5:
                                                if cif not in  colonna.var and cif not in riga and cif not in quadrato5.var: 
                                                        lista_cif.append(cif)

                                                        lista=[lista_cif,lista_pos]
                                                        dizio.var[str(conta)]=lista
                                            elif volte==6 or volte==7 or volte==8:
                                                if cif not in  colonna.var and cif not in riga and cif not in quadrato8.var: 
                                                        lista_cif.append(cif)

                                                        lista=[lista_cif,lista_pos]
                                                        dizio.var[str(conta)]=lista

                                                       # Sudoku.var[volte][z]=cif
                                else:
                                        for cif in numeri:
                                            if volte==0 or volte==1 or volte==2:
                                                if cif not in  colonna.var and cif not in riga and cif not in quadrato3.var:
                                                        lista_cif.append(cif)

                                                        lista=[lista_cif,lista_pos]
                                                        dizio.var[str(conta)]=lista
                                            elif volte==3 or volte==4 or volte==5:
                                                if cif not in  colonna.var and cif not in riga and cif not in quadrato6.var: 
                                                        lista_cif.append(cif)

                                                        lista=[lista_cif,lista_pos]
                                                        dizio.var[str(conta)]=lista
                                            elif volte==6 or volte==7 or volte==8:
                                                if cif not in  colonna.var and cif not in riga and cif not in quadrato9.var: 


                                                        lista_cif.append(cif)

                                                        lista=[lista_cif,lista_pos]
                                                        dizio.var[str(conta)]=lista

                        else:
                            pass
                   # if j=="":a

                         #   pass


                        lista_cif=[]
                        lista_pos=[]
                        lista=[]
    print("dizio.var len",len(dizio.var))
    #print("dizio ,funz algoritmo",dizio.var)
    print("contaspazi",contaspazi)
algoritmo()

def lista_sol():
    lista_sol.var=""
lista_sol()
def filtro_iniziale():
    print("execute initial filtering")
    print("filtraggio in base alle cifre iniziali")
    print("numero di permutazioni  rimanenti per ogni riga dopo il filtraggio ")
    sol1,sol2,sol3,sol4,sol5,sol6,sol7,sol8,sol9=[],[],[],[],[],[],[],[],[]
    conta_sud=-1
    lista_ind1,lista_ind2,lista_ind3,lista_ind4,lista_ind5,lista_ind6,lista_ind7,lista_ind8,lista_ind9=[],[],[],[],[],[],[],[],[]

    s1,s2,s3,s4,s5,s6,s7,s8,s9=[],[],[],[],[],[],[],[],[]
    lista_lista_ind=[lista_ind1,lista_ind2,lista_ind3,lista_ind4,lista_ind5,lista_ind6,lista_ind7,lista_ind8,lista_ind9]
    lista_s=[s1,s2,s3,s4,s5,s6,s7,s8,s9]
    lista_sol.var=[sol1,sol2,sol3,sol4,sol5,sol6,sol7,sol8,sol9]
    for sud in Sudoku.var:#FILTRA IN BASE CIFRE INIZIALI IN MODO CHE RIMANGANO NELLA LORO POSIZIONE
        #print(sud)
        conta_sud=conta_sud+1


        for x1 in numeri:
            if x1 not in sud:
                #print(x1)
                lista_s[conta_sud].append(x1)

        for x in range(0,len(a)):
            if sud[x]=="":
                index1=x

                lista_lista_ind[conta_sud].append(index1)#fino a qui funziona



        for v in itertools.permutations(lista_s[conta_sud]):
            lista=["","","","","","","","",""]

            conta=-1
           # print(v)

            for x3 in sud:
                conta=conta+1
              #  print(conta)
                #print(x3)


                for j ,y in zip(lista_lista_ind[conta_sud],v):
                    if x3=="":
                        lista[j]=y
                    else:
                        lista[conta]=x3

            lista_sol.var[conta_sud].append(lista)  
            
    for x in lista_sol.var:
            print(len(x))
    conta=-1
    for x in lista_sol.var:
            conta+=1
            if len(x)==1:
                if x not in l_p.var[conta]:
                    l_p.var[conta].append(x)
                print(x)
    print()
ccc=0

               # algoritmo()

              #  for x in range(len(lista_sol.var)):
               #     if len(lista_sol.var[x])==1:
                #        Sudoku.var[x]=lista_sol.var[x][0]
                 #       print(lista_sol.var[x][0],"ciaooooo")
               # dizio.var={}
               
quadrato1.var=Sudoku.var[0][0:3]+Sudoku.var[1][0:3]  +Sudoku.var[2][0:3]
quadrato2.var=Sudoku.var[0][3:6]+Sudoku.var[1][3:6]  +Sudoku.var[2][3:6]
quadrato3.var=Sudoku.var[0][6:9]+Sudoku.var[1][6:9]   +Sudoku.var[2][6:9]

quadrato4.var=Sudoku.var[3][0:3]+Sudoku.var[4][0:3]  +Sudoku.var[5][0:3]
quadrato5.var=Sudoku.var[3][3:6]+Sudoku.var[4][3:6]  +Sudoku.var[5][3:6]
quadrato6.var=Sudoku.var[3][6:9]+Sudoku.var[4][6:9]   +Sudoku.var[5][6:9]

quadrato7.var=Sudoku.var[6][0:3]+Sudoku.var[7][0:3]  +Sudoku.var[8][0:3]
quadrato8.var=Sudoku.var[6][3:6]+Sudoku.var[7][3:6]  +Sudoku.var[8][3:6]
quadrato9.var=Sudoku.var[6][6:9]+Sudoku.var[7][6:9]   +Sudoku.var[8][6:9]

                #filtro_iniziale()
                #filtro_iniziale()
algoritmo()
                #crea_funzione_check_colonne_e_quadrati()

                #filtro_iniziale()
                #crea_funzione_check_colonne_e_quadrati()
                #assegno_singola_cifra()

per=[]
lista1=[]
def L_F():
    L_F.var=3
L_F()
def listasoluzioni_finali():
      listasoluzioni_finali.var=[[] for x in range(9)]
listasoluzioni_finali()
def ulteriore_filtraggio_inbase_righe_colonne():
    soluzione1,soluzione2,soluzione3,soluzione4,soluzione5,soluzione6,soluzione7,soluzione8,soluzione9=[],[],[],[],[],[],[],[],[]
 #   print(dizio.var,"fjfffffffffffff")
    l_f=[]
    vero=[]
    intero1=0
    intero2=6
    n_lista=0
    n=0
    listasoluzioni_finali.var=[soluzione1,soluzione2,soluzione3,soluzione4,soluzione5,soluzione6,soluzione7,soluzione8,soluzione9]
    l_f1,l_f2,l_f3,l_f4,l_f5,l_f6,l_f7,l_f8,l_f9=[],[],[],[],[],[],[],[],[]
    L_F.var=[l_f1,l_f2,l_f3,l_f4,l_f5,l_f6,l_f7,l_f8,l_f9]
    c=0
    def partealgoritmo6x6():
        for x in range(82):#distribuisco il dizionario sulle varie righe

            if str(x) in dizio.var:

                if x<6:
                    L_F.var[0].append(dizio.var[str(x)])
                elif 6<=x<=11:
                    L_F.var[1].append(dizio.var[str(x)])
                elif 12<=x<=17:
                    L_F.var[2].append(dizio.var[str(x)])

                elif 18<=x<=23:
                    L_F.var[3].append(dizio.var[str(x)])
                elif 24<=x<=29:
                    L_F.var[4].append(dizio.var[str(x)])
                elif 30<=x<=35:
                    L_F.var[5].append(dizio.var[str(x)])
                        #l_f.append(dizio.var[str(x)])

    #a=["",4,1,"","",9,6,"",8] intervallo 0 - 8


    #b=[6,"","","","","","",3,""]intervallo 9 - 17

    #c=["","","",2,7,"","",9,""]intervallo 18 - 26

    #d=["",8,"","","","",1,5,""]intervallo 27 - 35
    #e=[3,5,"","","","","","",""]intervallo36 - 44
    #f=["","","","",6,8,"",2,""]intervallo45 - 53

    #g=[7,"",8,"","",5,"","",4]intervallo54 - 62
    #h=["","",9,4,"","",7,"",3]intervallo 63 -71
    #k=["","","",1,"","",2,"",""]intervallo 72 -80
                   # if x%6==0:
    #def partealgoritmo9x9():
    for x in range(82):#distribuisco il dizionario sulle varie righe

            if str(x) in dizio.var:

                if x<9:
                    L_F.var[0].append(dizio.var[str(x)])
                elif 9<=x<=17:
                    L_F.var[1].append(dizio.var[str(x)])
                elif 18<=x<=26:
                    L_F.var[2].append(dizio.var[str(x)])

                elif 27<=x<=35:
                    L_F.var[3].append(dizio.var[str(x)])
                elif 36<=x<=44:
                    L_F.var[4].append(dizio.var[str(x)])
                elif 45<=x<=53:
                    L_F.var[5].append(dizio.var[str(x)])
                elif 54<=x<=62:
                    L_F.var[6].append(dizio.var[str(x)])
                elif 63<=x<=71:
                    L_F.var[7].append(dizio.var[str(x)])
                elif 72<=x<=80:
                    L_F.var[8].append(dizio.var[str(x)])
                 #   L_F.append(dizio.var[str(x)])
    #print("lf1",L_F.var[1])
    #print(lista_sol[5],"sol5")
filtro_iniziale()
ulteriore_filtraggio_inbase_righe_colonne()
#print(L_F.var[0],"dddddddddd")
 #   for j in )

for hh in range(9):
    for x in lista_sol.var[hh]:
       # print("x",x)
        conta=0
        for j in L_F.var[hh]:
           # print(j,"j")
            cifre=j[0]
            indici=j[1]
            
           # print("cifre",cifre)
            #print("indici",indici)
            if x[indici[1]] in cifre:
             #   print("ciao")
                conta+=1
               # print("conta444",conta)
        if conta==len(L_F.var[hh]):#se le cifre delle permutazioni corrispondono alle cifre contenuto nella lista di cifre possibil
                    if x not in   listasoluzioni_finali.var[hh]:
                        listasoluzioni_finali.var[hh].append(x)
print("filtraggio in base alle cifre che può contenere ogni cella vuota")    
print("numero di permutazioni per ogni riga rimanenti dopo il filtraggio ")
for x in listasoluzioni_finali.var:
    print(len(x),"lenfin")
  #  print(x)

#spiegazione algorimtmo qui sotto: trova le soluzioni possibili delle prime 3 righe, poi righe 4,5,6 e poi delle righe 7,8,9
#poi crea una lista che contiene le soluzionepossibili delle prime  6  righe(prime3 righe piu riga 4,5,6) 
#infine fa scorrere le soluzioni delle prime 6 righe con le soluzioni delle ultime 3 righe finche trova la soluzione finale (tutte le righe si "incastrano tra loro")
listasolquad=[]
for j1 in listasoluzioni_finali.var[0]:
    Sudoku.var[0]=j1
    for j2 in listasoluzioni_finali.var[1]:
        Sudoku.var[1]=j2
        for j3 in listasoluzioni_finali.var[2]:
                Sudoku.var[2]=j3  
                quadrato1.var=Sudoku.var[0][0:3]+Sudoku.var[1][0:3]  +Sudoku.var[2][0:3]
                quadrato2.var=Sudoku.var[0][3:6]+Sudoku.var[1][3:6]  +Sudoku.var[2][3:6]
                quadrato3.var=Sudoku.var[0][6:9]+Sudoku.var[1][6:9]   +Sudoku.var[2][6:9]
                    #if len(list(set(quadrato1)))==len(quadrato1.var):
                lista_contr_colonne=[]
                for j in range(9):
                    colonna11= [row[j] for row in Sudoku.var[:3]]
                    colonna11_slice=colonna11[:3]
                    lista_contr_colonne.append(len(set(colonna11_slice))==len(colonna11_slice))
                lista_check22=  [len(list(set(quadrato1.var)))==len(quadrato1.var), len(list(set(quadrato2.var)))==len(quadrato2.var),len(list(set(quadrato3.var)))==len(quadrato3.var) ]
               
                if False not in lista_check22 and False not in lista_contr_colonne:
                    
                    #if j1 not in  listasoluzioni_fin2.var[0]:
                       # listasoluzioni_fin2.var[0].append( j1)
                    
                   # if j2 not in  listasoluzioni_fin2.var[1]:
                     #   listasoluzioni_fin2.var[1].append(  j2)
                    
                   # if j3 not in  listasoluzioni_fin2.var[2]:
                     #   listasoluzioni_fin2.var[2].append(  j3)
                    
                    listasolquad.append([j1,j2,j3])


listasolquad2=[]
for j4 in listasoluzioni_finali.var[3]:
    Sudoku.var[3]=j4
    for j5 in listasoluzioni_finali.var[4]:
        Sudoku.var[4]=j5
        for j6 in listasoluzioni_finali.var[5]:
                Sudoku.var[5]=j6
                quadrato4.var=Sudoku.var[3][0:3]+Sudoku.var[4][0:3]  +Sudoku.var[5][0:3]
                quadrato5.var=Sudoku.var[3][3:6]+Sudoku.var[4][3:6]  +Sudoku.var[5][3:6]
                quadrato6.var=Sudoku.var[3][6:9]+Sudoku.var[4][6:9]   +Sudoku.var[5][6:9]
                    #if len(list(set(quadrato1)))==len(quadrato1.var):
                lista_contr_colonne=[]
                for j in range(9):
                    colonna11= [row[j] for row in Sudoku.var[3:6]]
                    colonna11_slice=colonna11[:3]
                    lista_contr_colonne.append(len(set(colonna11_slice))==len(colonna11_slice))
                lista_check22=  [len(list(set(quadrato4.var)))==len(quadrato4.var), len(list(set(quadrato5.var)))==len(quadrato5.var),len(list(set(quadrato6.var)))==len(quadrato6.var) ]
                
                if False not in lista_check22 and False not in lista_contr_colonne:
                    #if j4 not in  listasoluzioni_fin2.var[3]:
                       # listasoluzioni_fin2.var[3].append( j4)
                    
                   # if j5 not in  listasoluzioni_fin2.var[4]:
                       # listasoluzioni_fin2.var[4].append(  j5)
                    
                    #if j6 not in  listasoluzioni_fin2.var[5]:
                        #listasoluzioni_fin2.var[5].append(  j6)
                    listasolquad2.append([j4,j5,j6])
                
listasolquad3=[]
for j7 in listasoluzioni_finali.var[6]:
    Sudoku.var[6]=j7
    for j8 in listasoluzioni_finali.var[7]:
        Sudoku.var[7]=j8
        for j9 in listasoluzioni_finali.var[8]:
                Sudoku.var[8]=j9
                quadrato7.var=Sudoku.var[6][0:3]+Sudoku.var[7][0:3]  +Sudoku.var[8][0:3]
                quadrato8.var=Sudoku.var[6][3:6]+Sudoku.var[7][3:6]  +Sudoku.var[8][3:6]
                quadrato9.var=Sudoku.var[6][6:9]+Sudoku.var[7][6:9]   +Sudoku.var[8][6:9]
                    #if len(list(set(quadrato1)))==len(quadrato1.var):
                lista_contr_colonne=[]
                for j in range(9):
                    colonna11= [row[j] for row in Sudoku.var[6:9]]
                    colonna11_slice=colonna11[:3]
                    lista_contr_colonne.append(len(set(colonna11_slice))==len(colonna11_slice))
                lista_check22=  [len(list(set(quadrato7.var)))==len(quadrato7.var), len(list(set(quadrato8.var)))==len(quadrato8.var),len(list(set(quadrato9.var)))==len(quadrato9.var) ]
                
                if False not in lista_check22 and False not in lista_contr_colonne:
                 
                    
                    #if j7 not in  listasoluzioni_fin2.var[6]:
                        #listasoluzioni_fin2.var[6].append(  j7)
                    
                    #if j8 not in  listasoluzioni_fin2.var[7]:
                       #listasoluzioni_fin2.var[7].append(  j8)          
                    
                    #if j9 not in  listasoluzioni_fin2.var[8]:
                       # listasoluzioni_fin2.var[8].append(  j9)
                    listasolquad3.append([j7,j8,j9])
                        
print()   

print("listasolquadlen",len(listasolquad))
print("listasolquadlen_2",len(listasolquad2))
print("listasolquadlen_3",len(listasolquad3))
#for x in listasoluzioni_fin2.var:
 #   print(len(x),"fin2len")
listaprimi6=[]
for j1 in listasolquad:
  #  print(j1)
    for j2 in listasolquad2:
        Sudoku.var=[j1[0],j1[1],j1[2],j2[0],j2[1],j2[2]]
        quadrato1.var=Sudoku.var[0][0:3]+Sudoku.var[1][0:3]  +Sudoku.var[2][0:3]
        quadrato2.var=Sudoku.var[0][3:6]+Sudoku.var[1][3:6]  +Sudoku.var[2][3:6]
        quadrato3.var=Sudoku.var[0][6:9]+Sudoku.var[1][6:9]   +Sudoku.var[2][6:9]
        quadrato4.var=Sudoku.var[3][0:3]+Sudoku.var[4][0:3]  +Sudoku.var[5][0:3]
        quadrato5.var=Sudoku.var[3][3:6]+Sudoku.var[4][3:6]  +Sudoku.var[5][3:6]
        quadrato6.var=Sudoku.var[3][6:9]+Sudoku.var[4][6:9]   +Sudoku.var[5][6:9]
        listaquad=[quadrato1.var,quadrato2.var,quadrato3.var,quadrato4.var,quadrato5.var,quadrato6.var]
                            #if len(list(set(quadrato1)))==len(quadrato1.var):  
                        #if len(list(set(quadrato1)))==len(quadrato1.var):
        lista_contr_colonne=[]
        for j in range(9):
                        colonna11= [row[j] for row in Sudoku.var]
                        colonna11_slice=colonna11
                        lista_contr_colonne.append(len(set(colonna11_slice))==len(colonna11_slice))
        lista_check22=  [len(list(set(quadrato1.var)))==len(quadrato1.var), len(list(set(quadrato2.var)))==len(quadrato2.var),len(list(set(quadrato3.var)))==len(quadrato3.var) ,

           len(list(set(quadrato4.var)))==len(quadrato4.var), len(list(set(quadrato5.var)))==len(quadrato5.var),len(list(set(quadrato6.var)))==len(quadrato6.var)]

        lista_check_col=[]
        for x44 in range(9):
                        col1=[row[x44] for row in Sudoku.var]
                        lista_check_col.append(len(list(set(col1)))==len(col1))
                        #lista_check_quad=[]
        lista_check_quad=[]
        for x66 in listaquad:
                        lista_check_quad.append(len(list(set(x66)))==len(x66))
        if False not in lista_check22 and False not in lista_contr_colonne:
            listaprimi6.append(j1+j2)
                   
    #print(x)
#print("primi6",len(listaprimi6)) 
#print("primi6",listaprimi6)
#for x in listaprimi6:
 #   print("x6",x)
#print()    

trovato=False
#def ciao():   
listaprimi9=[]
for j11 in listaprimi6:#se non interrompe questo ciclo quando trova la prima soluzione , riesce a trovare altre possibili soluzioni(sempre che esistono)
        #if trovato==True:#
         #   break
       # print(len(j1),"aaaaaaaaaaaaaaaaaaaaaaag")
        #print("1   ",j1)
    #def ciao():   
        for j2 in listasolquad3:
         #   print("2 j3    ",j2)
        #    print(len(j2),"jjjjjjjjjjjjjjjjjjjjb")
#def ciao()

            Sudoku.var=[j11[0],j11[1],j11[2],j11[3],j11[4],j11[5],j2[0],j2[1],j2[2]]
            quadrato1.var=Sudoku.var[0][0:3]+Sudoku.var[1][0:3]  +Sudoku.var[2][0:3]
            quadrato2.var=Sudoku.var[0][3:6]+Sudoku.var[1][3:6]  +Sudoku.var[2][3:6]
            quadrato3.var=Sudoku.var[0][6:9]+Sudoku.var[1][6:9]   +Sudoku.var[2][6:9]
            quadrato4.var=Sudoku.var[3][0:3]+Sudoku.var[4][0:3]  +Sudoku.var[5][0:3]
            quadrato5.var=Sudoku.var[3][3:6]+Sudoku.var[4][3:6]  +Sudoku.var[5][3:6]
            quadrato6.var=Sudoku.var[3][6:9]+Sudoku.var[4][6:9]   +Sudoku.var[5][6:9]
            quadrato7.var=Sudoku.var[6][0:3]+Sudoku.var[7][0:3]  +Sudoku.var[8][0:3]
            quadrato8.var=Sudoku.var[6][3:6]+Sudoku.var[7][3:6]  +Sudoku.var[8][3:6]
            quadrato9.var=Sudoku.var[6][6:9]+Sudoku.var[7][6:9]   +Sudoku.var[8][6:9]
            listaquad=[quadrato1.var,quadrato2.var,quadrato3.var,quadrato4.var,quadrato5.var,quadrato6.var,quadrato7.var,quadrato8.var,quadrato9.var]
                            #if len(list(set(quadrato1)))==len(quadrato1.var):
            lista_contr_colonne=[]
            for j in range(9):
                            colonna11= [row[j] for row in Sudoku.var]
                            colonna11_slice=colonna11
                            lista_contr_colonne.append(len(set(colonna11_slice))==len(colonna11_slice))
            lista_check22=  [len(list(set(quadrato1.var)))==len(quadrato1.var), len(list(set(quadrato2.var)))==len(quadrato2.var),len(list(set(quadrato3.var)))==len(quadrato3.var) ,

               len(list(set(quadrato4.var)))==len(quadrato4.var), len(list(set(quadrato5.var)))==len(quadrato5.var),len(list(set(quadrato6.var)))==len(quadrato6.var),
                            len(list(set(quadrato7.var)))==len(quadrato7.var), len(list(set(quadrato8.var)))==len(quadrato8.var),len(list(set(quadrato9.var)))==len(quadrato9.var)
                            ]

            lista_check_col=[]
            for x44 in range(9):
                            col1=[row[x44] for row in Sudoku.var]
                            lista_check_col.append(len(list(set(col1)))==len(col1))
                            #lista_check_quad=[]
            for x66 in listaquad:
                            lista_check_quad.append(len(list(set(x66)))==len(x66))
            if False not in lista_check22 and False not in lista_contr_colonne:
                #listaprimi9.append([j1,j2])
                soluzione=j11+j2
                print("soluzione=?")
                for x in soluzione:
                    print(x)
                #for x,sol in zip(soluzione,listasoluzioniesperto):
                 #   if sol== x:
                  #      print("ok")
                   # else:
                    #    print("errore")
                #trovato=True
                fine= datetime.now()
                print("il sudoku è stato risolto in ",fine-inizio) 
                #Sudoku.var[7][1]=3
                print(crea_funzione_check_colonne_e_quadrati())
                print()
                break
                #print()
# Out:
# [[], [], [], [], [], [], [], [], []]
# Sudoku iniziale
# ['', '', 5, '', '', 8, 3, 9, '']
# ['', 3, '', '', '', '', '', '', '']
# ['', '', '', 7, '', '', '', 8, '']
# ['', '', 4, 5, '', '', 6, '', 2]
# [6, 1, '', '', '', '', '', '', '']
# [2, '', '', '', 4, 9, '', '', '']
# ['', '', '', '', '', 2, 4, '', 5]
# ['', '', 9, '', 8, '', '', '', '']
# [5, 6, '', '', '', '', '', '', '']
#
# dizio.var len 58
# contaspazi 58
# dizio.var len 58
# contaspazi 58
# execute initial filtering
# filtraggio in base alle cifre iniziali
# numero di permutazioni  rimanenti per ogni riga dopo il filtraggio
# 120
# 40320
# 5040
# 120
# 5040
# 720
# 720
# 5040
# 5040
#
# filtraggio in base alle cifre che può contenere ogni cella vuota
# numero di permutazioni per ogni riga rimanenti dopo il filtraggio
# 20 lenfin
# 451 lenfin
# 42 lenfin
# 12 lenfin
# 10 lenfin
# 24 lenfin
# 38 lenfin
# 52 lenfin
# 164 lenfin
#
# listasolquadlen 1735
# listasolquadlen_2 56
# listasolquadlen_3 1696
# soluzione=?
# [7, 4, 5, 2, 1, 8, 3, 9, 6]
# [8, 3, 2, 4, 9, 6, 1, 5, 7]
# [1, 9, 6, 7, 5, 3, 2, 8, 4]
# [9, 8, 4, 5, 3, 1, 6, 7, 2]
# [6, 1, 3, 8, 2, 7, 5, 4, 9]
# [2, 5, 7, 6, 4, 9, 8, 3, 1]
# [3, 7, 8, 9, 6, 2, 4, 1, 5]
# [4, 2, 9, 1, 8, 5, 7, 6, 3]
# [5, 6, 1, 3, 7, 4, 9, 2, 8]
# il sudoku è stato risolto in  0:01:09.194977
# non ci sono errori

# %%
import tkinter as tk
from tkinter import *#eseguire la funzione per inserire più facilmente un sudoku.
#questa funzine apre una GUI di tk inter e  stampa un nuovo sudoku qui sotto.
#poi bisogna copiarlo di sopra in modo che possa essere risolto dal programma
def inputsudoku():#bisogna copiare e incollare il sudoku che stampa una volta inserite le cifre
    dizio={}
    #entry1 = tk.Entry (root) 
    #canvas1.create_window(200, 140, window=entry1)
    for jj in range(1,82):
        stringa = 'entry'+str(jj)
       # print(string)


        locals()[stringa] = 5000
        dizio[str(jj)]=locals()[stringa]
    print(dizio)
   # print(entry55,"ddddddddddda")   
   
    root= tk.Tk()
    root.title("place() method")
    canvas1 = tk.Canvas(root, width = 1000, height = 1000)
    canvas1.pack()
    def ciao():
        for jj in range(1,82):
            stringa = 'entry'+str(jj)
           # print(string)


            locals()[stringa] = 5000
        print(dizio)
        print(entry55,"")   
        #for yy in listof_variables:
          #  print(yy)
    #for j in dizio:
     #   dizio[j]=tk.Entry (root) 
            #namestr(x, globals())
    iterate=0

    print(dizio)
    print(dizio["33"],"ddddddf")
    v,z=30,30
    n=0 
    a,b,c,d,e,f,g,h,k=["","","","","","","","",""],["","","","","","","","",""],["","","","","","","","",""],["","","","","","","","",""],["","","","","","","","",""],["","","","","","","","",""],["","","","","","","","",""],["","","","","","","","",""],["","","","","","","","",""]
    def Sudoku():
                    Sudoku.var=[a,b,c,d,e,f,g,h,k]

    Sudoku()
    for x in range(9):


            z=z+100
            for y in range(9):
                iterate=iterate+1
               # entry1 = tk.Entry (root) 
                #canvas1.create_window(z, h, window=entry1)
                v=v+20


                dizio[str(iterate)] = tk.Entry (root,width=10) 
                canvas1.create_window(z, v, window=  dizio[str(iterate)]  )
                #Label(root, text= dizio[str(z)], font= ('Century 15 bold')).pack(pady=20)  


            v=30
    print(dizio)
    print("dizio35",dizio["35"])
    sudoku3=[]
    Sudoku2=[[] ,[] ,[] ,[] ,[] ,[] ,[] ,[] ,[]]

    def conta222():
        conta222.var=-1
    conta222()

    def indice():
        indice.var=-1
    indice()
    def get_value():

                conta=0
                for cc in dizio:#inserisce correttamente i valori solo la prima volta, poi se inserisco altri valori invece di definire un nuovo sudoku stampa ancora il sudoku che ho inserito la prima volta
                    conta=conta+1

                    #riesce a stampare i numerini, tranne alcuni
                    e_text=dizio[cc].get()
                    #print(e_text)
                    sudoku3.append(e_text)
                 #   Label(root, text=e_text, font= ('Century 15 bold')).pack(pady=20)
                #Create an Entry Widget
               # print(sudoku3)
                #conta2=-1
                conta11=-1
                conta13=-1
                for x in sudoku3:
                    conta11=conta11+1

                    if conta11%9==0:
                        conta13=conta13+1
                        conta11=0
                    if x!="":
                        intero=int(x, 10)
                    else:
                        intero=""
                   # print(conta13,conta11)
                    if conta11<9 and conta13<9:
                        Sudoku.var[conta11][conta13]=intero#le cifre vengono inserite come numeri decimali,

               # conta11=0
                #conta13=0
                #print("idnicifinali",conta11,conta13)    
                #print("indice",indice.var)
                #print("conta222",conta222.var)
                #  Sudoku.var[conta][conta1]=x
                    #conta1=0
                #Create a button to display the text of entry widget
                def ciao():
                    j=200
                    for x in Sudoku.var:
                        j=j+20
                        scrivi_sudoku = Label(root, text = str(x)).place(x = 400, y = j)  
                window = tk.Tk()
                for i in range(len(Sudoku.var)):
                    for j in range(len(Sudoku.var)):
    #tkinter.ttk.Separator(window, orient=VERTICAL)
    #canvas.create_line(300, 35, 300, 200, dash=(4, 2))
                        frame = tk.Frame(
                        master=window,
                        relief=tk.RAISED,
                        borderwidth=1
                        )
                        frame.grid(row=i, column=j, padx=len(a), pady=len(a))
                        label = tk.Label(master=frame, text=str(Sudoku.var[i][j]))
                        label.pack(padx=5, pady=5 )

                lettere="abcdefghk"
                for x,y in zip(Sudoku.var,lettere): 

                        print(str(y)+"="+str(x))

                print() 

                window.mainloop()   
                print()
                root.mainloop()

    button = tk.Button(root, text="Click to insert Sudoku", command=get_value)
    button.place(x=500, y=225)
    #Create a Label


    root.mainloop()
inputsudoku()
# Out:
# {'1': 5000, '2': 5000, '3': 5000, '4': 5000, '5': 5000, '6': 5000, '7': 5000, '8': 5000, '9': 5000, '10': 5000, '11': 5000, '12': 5000, '13': 5000, '14': 5000, '15': 5000, '16': 5000, '17': 5000, '18': 5000, '19': 5000, '20': 5000, '21': 5000, '22': 5000, '23': 5000, '24': 5000, '25': 5000, '26': 5000, '27': 5000, '28': 5000, '29': 5000, '30': 5000, '31': 5000, '32': 5000, '33': 5000, '34': 5000, '35': 5000, '36': 5000, '37': 5000, '38': 5000, '39': 5000, '40': 5000, '41': 5000, '42': 5000, '43': 5000, '44': 5000, '45': 5000, '46': 5000, '47': 5000, '48': 5000, '49': 5000, '50': 5000, '51': 5000, '52': 5000, '53': 5000, '54': 5000, '55': 5000, '56': 5000, '57': 5000, '58': 5000, '59': 5000, '60': 5000, '61': 5000, '62': 5000, '63': 5000, '64': 5000, '65': 5000, '66': 5000, '67': 5000, '68': 5000, '69': 5000, '70': 5000, '71': 5000, '72': 5000, '73': 5000, '74': 5000, '75': 5000, '76': 5000, '77': 5000, '78': 5000, '79': 5000, '80': 5000, '81': 5000}
# {'1': 5000, '2': 5000, '3': 5000, '4': 5000, '5': 5000, '6': 5000, '7': 5000, '8': 5000, '9': 5000, '10': 5000, '11': 5000, '12': 5000, '13': 5000, '14': 5000, '15': 5000, '16': 5000, '17': 5000, '18': 5000, '19': 5000, '20': 5000, '21': 5000, '22': 5000, '23': 5000, '24': 5000, '25': 5000, '26': 5000, '27': 5000, '28': 5000, '29': 5000, '30': 5000, '31': 5000, '32': 5000, '33': 5000, '34': 5000, '35': 5000, '36': 5000, '37': 5000, '38': 5000, '39': 5000, '40': 5000, '41': 5000, '42': 5000, '43': 5000, '44': 5000, '45': 5000, '46': 5000, '47': 5000, '48': 5000, '49': 5000, '50': 5000, '51': 5000, '52': 5000, '53': 5000, '54': 5000, '55': 5000, '56': 5000, '57': 5000, '58': 5000, '59': 5000, '60': 5000, '61': 5000, '62': 5000, '63': 5000, '64': 5000, '65': 5000, '66': 5000, '67': 5000, '68': 5000, '69': 5000, '70': 5000, '71': 5000, '72': 5000, '73': 5000, '74': 5000, '75': 5000, '76': 5000, '77': 5000, '78': 5000, '79': 5000, '80': 5000, '81': 5000}
# 5000 ddddddf
# {'1': <tkinter.Entry object .!entry>, '2': <tkinter.Entry object .!entry2>, '3': <tkinter.Entry object .!entry3>, '4': <tkinter.Entry object .!entry4>, '5': <tkinter.Entry object .!entry5>, '6': <tkinter.Entry object .!entry6>, '7': <tkinter.Entry object .!entry7>, '8': <tkinter.Entry object .!entry8>, '9': <tkinter.Entry object .!entry9>, '10': <tkinter.Entry object .!entry10>, '11': <tkinter.Entry object .!entry11>, '12': <tkinter.Entry object .!entry12>, '13': <tkinter.Entry object .!entry13>, '14': <tkinter.Entry object .!entry14>, '15': <tkinter.Entry object .!entry15>, '16': <tkinter.Entry object .!entry16>, '17': <tkinter.Entry object .!entry17>, '18': <tkinter.Entry object .!entry18>, '19': <tkinter.Entry object .!entry19>, '20': <tkinter.Entry object .!entry20>, '21': <tkinter.Entry object .!entry21>, '22': <tkinter.Entry object .!entry22>, '23': <tkinter.Entry object .!entry23>, '24': <tkinter.Entry object .!entry24>, '25': <tkinter.Entry object .!entry25>, '26': <tkinter.Entry object .!entry26>, '27': <tkinter.Entry object .!entry27>, '28': <tkinter.Entry object .!entry28>, '29': <tkinter.Entry object .!entry29>, '30': <tkinter.Entry object .!entry30>, '31': <tkinter.Entry object .!entry31>, '32': <tkinter.Entry object .!entry32>, '33': <tkinter.Entry object .!entry33>, '34': <tkinter.Entry object .!entry34>, '35': <tkinter.Entry object .!entry35>, '36': <tkinter.Entry object .!entry36>, '37': <tkinter.Entry object .!entry37>, '38': <tkinter.Entry object .!entry38>, '39': <tkinter.Entry object .!entry39>, '40': <tkinter.Entry object .!entry40>, '41': <tkinter.Entry object .!entry41>, '42': <tkinter.Entry object .!entry42>, '43': <tkinter.Entry object .!entry43>, '44': <tkinter.Entry object .!entry44>, '45': <tkinter.Entry object .!entry45>, '46': <tkinter.Entry object .!entry46>, '47': <tkinter.Entry object .!entry47>, '48': <tkinter.Entry object .!entry48>, '49': <tkinter.Entry object .!entry49>, '50': <tkinter.Entry object .!entry50>, '51': <tkinter.Entry object .!entry51>, '52': <tkinter.Entry object .!entry52>, '53': <tkinter.Entry object .!entry53>, '54': <tkinter.Entry object .!entry54>, '55': <tkinter.Entry object .!entry55>, '56': <tkinter.Entry object .!entry56>, '57': <tkinter.Entry object .!entry57>, '58': <tkinter.Entry object .!entry58>, '59': <tkinter.Entry object .!entry59>, '60': <tkinter.Entry object .!entry60>, '61': <tkinter.Entry object .!entry61>, '62': <tkinter.Entry object .!entry62>, '63': <tkinter.Entry object .!entry63>, '64': <tkinter.Entry object .!entry64>, '65': <tkinter.Entry object .!entry65>, '66': <tkinter.Entry object .!entry66>, '67': <tkinter.Entry object .!entry67>, '68': <tkinter.Entry object .!entry68>, '69': <tkinter.Entry object .!entry69>, '70': <tkinter.Entry object .!entry70>, '71': <tkinter.Entry object .!entry71>, '72': <tkinter.Entry object .!entry72>, '73': <tkinter.Entry object .!entry73>, '74': <tkinter.Entry object .!entry74>, '75': <tkinter.Entry object .!entry75>, '76': <tkinter.Entry object .!entry76>, '77': <tkinter.Entry object .!entry77>, '78': <tkinter.Entry object .!entry78>, '79': <tkinter.Entry object .!entry79>, '80': <tkinter.Entry object .!entry80>, '81': <tkinter.Entry object .!entry81>}
# dizio35 .!entry35
# a=[9, 2, 6, '', '', 8, '', 1, '']
# b=['', 5, 8, '', 2, '', 3, '', 7]
# c=['', '', '', 5, '', '', 8, 2, '']
# d=['', 9, '', '', 5, 7, '', '', '']
# e=['', '', 3, 9, '', '', '', 7, '']
# f=['', '', '', 6, 1, '', '', '', 5]
# g=[4, 6, '', '', '', '', 7, '', '']
# h=['', '', '', '', '', '', '', 8, '']
# k=[2, '', 1, '', '', '', 6, 9, '']
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Attilio\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "<ipython-input-19-825d7b38175b>", line 139, in get_value
#     window.mainloop()
#   File "C:\Users\Attilio\anaconda3\lib\tkinter\__init__.py", line 1429, in mainloop
#     self.tk.mainloop(n)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-825d7b38175b> in <module>
#     147
#     148     root.mainloop()
# --> 149 inputsudoku()
#
# <ipython-input-19-825d7b38175b> in inputsudoku()
#     146
#     147
# --> 148     root.mainloop()
#     149 inputsudoku()
#
# ~\anaconda3\lib\tkinter\__init__.py in mainloop(self, n)
#    1427     def mainloop(self, n=0):
#    1428         """Call the mainloop of Tk."""
# -> 1429         self.tk.mainloop(n)
#    1430
#    1431     def quit(self):
#
# KeyboardInterrupt:

# %%
def findsquares():#generico, trova i quadrati indipendentemente dal tipo di sudoku
    for j in range(len(sudoku1)):
            #square=[]
       
            for y in range(len(sudoku1)):
           
                if len(sudoku1)==9: 
                   if j==0 or j==3 or j==6:
                        if y<=6 and y%3==0:
                        #quadrato1.var=Sudoku.var[0][0:3]+Sudoku.var[1][0:3]  +Sudoku.var[2][0:3]
                        #    square=sudoku1[j:j+3][y:y+3]
                            square=sudoku1[j][y:y+3]+sudoku1[j+1][y:y+3]  +sudoku1[j+2][y:y+3]
                            lista_quad.append(square)
                elif len(sudoku1)==6:
                      if j==0 or j==2 or j==4:
                        if y<=3 and y%3==0:
                        #quadrato1.var=Sudoku.var[0][0:3]+Sudoku.var[1][0:3]  +Sudoku.var[2][0:3]
                        #    square=sudoku1[j:j+3][y:y+3]
                            square=sudoku1[j][y:y+3]+sudoku1[j+1][y:y+3] 
                            lista_quad.append(square)

# %%
def assegno_singola_cifra():
    print("esec function")

    for int_chiave in range(len(dizio.var)):
        if str(int_chiave) in dizio.var:
            if len(dizio.var[str(int_chiave)][0])==1:#se ho la certezza che una cifra sia la soluzione in quella posizione, la assegno
             #   print("dizio",dizio.var[str(int_chiave)])

    #for j in lista_sol[1]:

                indice22= dizio.var[str(int_chiave)][1][0]

                riga=indice22
                verticale=dizio.var[str(int_chiave)][1][1]
               # print("riga",Sudoku.var[riga])
                if riga<3:
                                            if verticale<3:
                                        #for cif in numeri:


                                                indice_quadrato=0
                                            elif 3<=verticale<=5:
                                        #    elif volte==3 or volte==4 or volte==5:
                                                indice_quadrato=1
                                            else:
                                                indice_quadrato=2

                elif 3<=riga<=5:
                                            if verticale<3:
                                        #for cif in numeri:


                                                indice_quadrato=3
                                            elif 3<=verticale<=5:
                                        #    elif volte==3 or volte==4 or volte==5:
                                                indice_quadrato=4
                                            else:
                                                indice_quadrato=5

                else:
                                            if verticale<3:
                                        #for cif in numeri:


                                                indice_quadrato=6
                                            elif 3<=verticale<=5:
                                        #    elif volte==3 or volte==4 or volte==5:
                                                indice_quadrato=7
                                            else:
                                                indice_quadrato=8
               # print("indice_quadrato",indice_quadrato)

                #print("aaaaaaaaaaaaaaaa",dizio.var[str(int_chiave)][0][0 ])
                #print("bbbbbbbbbbb",dizio.var[str(int_chiave)][1][0])
                #print("ccccccccccc",dizio.var[str(int_chiave)][1][1])

                
               # for jj in len(Sudoku.var):
                    #for z in len(Sudoku.var):
               ## crea_funzione_check_colonne_e_quadrati()
               # colonna= [row[indice22] for row in Sudoku.var]
        #        print(colonna,"CColonna")
                #        lista.append(colonna)
                listaquadrati=[quadrato1.var,quadrato2.var,quadrato3.var,quadrato4.var,quadrato5.var,quadrato6.var,quadrato7.var,quadrato8.var,quadrato9.var]
                if dizio.var[str(int_chiave)][0][0] not in listaquadrati[indice_quadrato] and  dizio.var[str(int_chiave)][0][0] not in Sudoku.var[riga] and      dizio.var[str(int_chiave)][0][0] not in  CHECK_colonna.var[verticale]:         
                    Sudoku.var[dizio.var[str(int_chiave)][1][0]][dizio.var[str(int_chiave)][1][1]]=dizio.var[str(int_chiave)][0][0]
                    print("cifra assegnata=",dizio.var[str(int_chiave)][0][0],"       posizione ",dizio.var[str(int_chiave)][1][0],dizio.var[str(int_chiave)][1][1])
                #else:
                 #   print("error1!")
